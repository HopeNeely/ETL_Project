# %% [markdown]
# # ETL_WineXL_CleanUP

# %% [markdown]
# #### Comments on ETL_WineXL_CleanUp
# ###### 1) Since the file we were cleaning up was a .xlxs, we needed to install openpyxl and then use that as our engine to read the excel file
# ###### 2) Eliminated Vintage, County and Designation columns
# ###### 3) Determined that there were incomplete rows and then eliminated those rows
# ###### 4) Evaluated data to determine if the data was of the appropriate type. Noted that Price was an object rather than a float
# ###### 5) Converted the price column to a float
# ###### 6) Eliminated all wines that were not include in the top 6 favorite wines per the Art Wine Preserve website
# ###### 7) Reindexed the DataFrame after eliminating non-top 6 wines

# %%
import pandas as pd
from sqlalchemy import create_engine
#!pip install openpyxl
#!pip install psycopg2
import psycopg2 as pg2

# %%
#### Store xlsx into a DataFrame

# %%
data_file = "Resources/Wines.xlsx"
df = pd.read_excel(data_file, engine='openpyxl')
df.head()
# Out:
#                Vintage   Country                           County  \
# 0  1919-01-01 00:00:00     Spain                             Cava
# 1  1929-01-01 00:00:00     Italy       Vernaccia di San Gimignano
# 2  1929-01-01 00:00:00     Italy  Sangiovese di Romagna Superiore
# 3  1934-01-01 00:00:00  Portugal                              NaN
# 4  1945-01-01 00:00:00    France                       Rivesaltes
#
#           Designation  Points    Price              Province  \
# 0  1919 Brut Selecció      88   $13.00             Catalonia
# 1                 NaN      87   $14.00               Tuscany
# 2            Prugneto      84   $15.00         Central Italy
# 3       Reserva Velho      93  $495.00               Colares
# 4      Legend Vintage      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecció Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Gérard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Gérard Bertrand

# %%
pd.Series(type(x) for x in df['Vintage']).unique()
# Out:
# array([<class 'datetime.datetime'>, <class 'str'>], dtype=object)

# %%
df["Vintage"] = pd.to_datetime(df['Vintage'], infer_datetime_format=True)
df.head()
# Out:
#      Vintage   Country                           County         Designation  \
# 0 1919-01-01     Spain                             Cava  1919 Brut Selecció
# 1 1929-01-01     Italy       Vernaccia di San Gimignano                 NaN
# 2 1929-01-01     Italy  Sangiovese di Romagna Superiore            Prugneto
# 3 1934-01-01  Portugal                              NaN       Reserva Velho
# 4 1945-01-01    France                       Rivesaltes      Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecció Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Gérard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Gérard Bertrand

# %%
df["Vintage"] = pd.Series(x.year for x in df["Vintage"])
df.head()
# Out:
#    Vintage   Country                           County         Designation  \
# 0     1919     Spain                             Cava  1919 Brut Selecció
# 1     1929     Italy       Vernaccia di San Gimignano                 NaN
# 2     1929     Italy  Sangiovese di Romagna Superiore            Prugneto
# 3     1934  Portugal                              NaN       Reserva Velho
# 4     1945    France                       Rivesaltes      Legend Vintage
#
#    Points    Price              Province  \
# 0      88   $13.00             Catalonia
# 1      87   $14.00               Tuscany
# 2      84   $15.00         Central Italy
# 3      93  $495.00               Colares
# 4      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecció Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Gérard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Gérard Bertrand

# %%
df.dtypes
# Out:
# Vintage         int64
# Country        object
# County         object
# Designation    object
# Points          int64
# Price          object
# Province       object
# Title          object
# Variety        object
# Winery         object
# dtype: object

# %% [markdown]
# #### Eliminate unnecessary columns

# %%
new_df = df[['Vintage','Country', 'Points', "Price", 'Province', 'Title', 'Variety', 'Winery']].copy()
new_df.head()
# Out:
#    Vintage   Country  Points    Price              Province  \
# 0     1919     Spain      88   $13.00             Catalonia
# 1     1929     Italy      87   $14.00               Tuscany
# 2     1929     Italy      84   $15.00         Central Italy
# 3     1934  Portugal      93  $495.00               Colares
# 4     1945    France      95  $350.00  Languedoc-Roussillon
#
#                                                Title          Variety  \
# 0     L'Arboc NV 1919 Brut Selecció Sparkling (Cava)  Sparkling Blend
# 1         Guidi 1929 2015 Vernaccia di San Gimignano        Vernaccia
# 2  Poderi dal Nespoli 1929 2011 Prugneto (Sangiov...       Sangiovese
# 3  Adega Viuva Gomes 1934 Reserva Velho Red (Cola...          Ramisco
# 4  Gérard Bertrand 1945 Legend Vintage Red (Rives...        Red Blend
#
#                     Winery
# 0                  L'Arboc
# 1               Guidi 1929
# 2  Poderi dal Nespoli 1929
# 3        Adega Viuva Gomes
# 4          Gérard Bertrand

# %% [markdown]
# #### Check to see if all rows have complete data

# %%
new_df.count()
# Out:
# Vintage     24997
# Country     24989
# Points      24997
# Price       23375
# Province    24989
# Title       24997
# Variety     24997
# Winery      24997
# dtype: int64

# %% [markdown]
# #### Eliminate rows with incomplete data

# %%
new_df = new_df.dropna(how='any')
new_df.count()
# Out:
# Vintage     23367
# Country     23367
# Points      23367
# Price       23367
# Province    23367
# Title       23367
# Variety     23367
# Winery      23367
# dtype: int64

# %% [markdown]
# #### Determine if all columns are set up in the correct data type

# %%
new_df.dtypes
# Out:
# Vintage      int64
# Country     object
# Points       int64
# Price       object
# Province    object
# Title       object
# Variety     object
# Winery      object
# dtype: object

# %% [markdown]
# ###### Note: price should be a float

# %% [markdown]
# #### Convert the Price columnt to float

# %%
new_df['Price'] = [float(x.replace("$","").replace(",","")) for x in new_df['Price']]
new_df.dtypes
# Out:
# Vintage       int64
# Country      object
# Points        int64
# Price       float64
# Province     object
# Title        object
# Variety      object
# Winery       object
# dtype: object

# %%
new_df = new_df.loc[(new_df['Country'] == "US")]
new_df
# Out:
#        Vintage Country  Points  Price    Province  \
# 11        1987      US      89  170.0  California
# 15        1991      US      93   60.0  California
# 16        1992      US      88   22.0  California
# 17        1992      US      91   32.0  California
# 19        1993      US      86   24.0      Oregon
# ...        ...     ...     ...    ...         ...
# 24977     2016      US      91   23.0  California
# 24978     2016      US      86   16.0    New York
# 24980     2016      US      90   22.0  California
# 24984     2016      US      90   23.0  California
# 24990     2016      US      90   24.0    New York
#
#                                                    Title             Variety  \
# 11     Sebastiani 1987 Cherryblock Cabernet Sauvignon...  Cabernet Sauvignon
# 15             Iron Horse 1991 Brut L.D. (Sonoma County)     Champagne Blend
# 16        Gloria Ferrer 1992 Royal Cuvee Brut (Carneros)     Champagne Blend
# 17     Pacific Echo 1992 Private Reserve Brut (Anders...     Champagne Blend
# 19                                  Rex Hill 1993 Oregon     Champagne Blend
# ...                                                  ...                 ...
# 24977   Saracina 2016 Sauvignon Blanc (Mendocino County)     Sauvignon Blanc
# 24978  Hosmer 2016 Estate Winery Pinot Gris (Cayuga L...          Pinot Gris
# 24980    C R Graybehl 2016 Grenache Rosé (Sonoma Valley)                Rosé
# 24984  Belharra 2016 Las Madres Vineyards Rosé of Syr...               Syrah
# 24990  Wölffer 2016 Summer in a Bottle Rosé (Long Isl...                Rosé
#
#               Winery
# 11        Sebastiani
# 15        Iron Horse
# 16     Gloria Ferrer
# 17      Pacific Echo
# 19          Rex Hill
# ...              ...
# 24977       Saracina
# 24978         Hosmer
# 24980   C R Graybehl
# 24984       Belharra
# 24990        Wölffer
#
# [10538 rows x 8 columns]

# %% [markdown]
# #### Isolate the top 6 wine types per https://artwinepreserver.com/: Cabernet Sauvignon, Chardonnay, Pinot Gris/Pinot Grigio, Pinot Noir, Sauvignon Blanc, Merlot (Pinot Gris/Pinot Grigio - Pinot Gris in this dataset)

# %%
winexl_df = new_df.loc[(new_df['Variety'] == "Cabernet Sauvignon") | (new_df['Variety'] == "Chardonnay") 
                       | (new_df['Variety'] == "Pinot Gris") | (new_df['Variety'] == "Pinot Noir")
                       | (new_df['Variety'] == "Sauvignon Blanc") | (new_df['Variety'] == "Merlot")]
count = winexl_df['Variety'].value_counts()
count
# Out:
# Pinot Noir            1953
# Cabernet Sauvignon    1428
# Chardonnay            1336
# Sauvignon Blanc        459
# Merlot                 419
# Pinot Gris             172
# Name: Variety, dtype: int64

# %%
winexl_df.head()
# Out:
#     Vintage Country  Points  Price    Province  \
# 11     1987      US      89  170.0  California
# 23     1994      US      82   13.0  California
# 36     1996      US      83   22.0  California
# 37     1996      US      84   29.0  Washington
# 38     1996      US      88   35.0  California
#
#                                                 Title             Variety  \
# 11  Sebastiani 1987 Cherryblock Cabernet Sauvignon...  Cabernet Sauvignon
# 23           Gan Eden 1994 Chardonnay (Sonoma County)          Chardonnay
# 36  Meridian 1996 Coastal Reserve Cabernet Sauvign...  Cabernet Sauvignon
# 37  Covey Run 1996 Whiskey Canyon Vyd Cabernet Sau...  Cabernet Sauvignon
# 38  Château Souverain 1996 Winemaker's Reserve Cab...  Cabernet Sauvignon
#
#                Winery
# 11         Sebastiani
# 23           Gan Eden
# 36           Meridian
# 37          Covey Run
# 38  Château Souverain

# %%
winexl_df = winexl_df.reset_index(drop=True)
winexl_df.head()
# Out:
#    Vintage Country  Points  Price    Province  \
# 0     1987      US      89  170.0  California
# 1     1994      US      82   13.0  California
# 2     1996      US      83   22.0  California
# 3     1996      US      84   29.0  Washington
# 4     1996      US      88   35.0  California
#
#                                                Title             Variety  \
# 0  Sebastiani 1987 Cherryblock Cabernet Sauvignon...  Cabernet Sauvignon
# 1           Gan Eden 1994 Chardonnay (Sonoma County)          Chardonnay
# 2  Meridian 1996 Coastal Reserve Cabernet Sauvign...  Cabernet Sauvignon
# 3  Covey Run 1996 Whiskey Canyon Vyd Cabernet Sau...  Cabernet Sauvignon
# 4  Château Souverain 1996 Winemaker's Reserve Cab...  Cabernet Sauvignon
#
#               Winery
# 0         Sebastiani
# 1           Gan Eden
# 2           Meridian
# 3          Covey Run
# 4  Château Souverain

# %%
#Create connection with PostgreSQL
#rds_connection_string = "<postgress>:<Todayis11222020!>@localhost:5432/customer_db"
#conn = pg2.connect(database='wines',user='postgres', password=Todayis11222020!)
#engine = create_engine(f'postgresql://{rds_connection_string}')
